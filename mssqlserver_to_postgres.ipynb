# %%
import pandas as pd
import pyodbc
import os
import re
from sqlalchemy import create_engine


################################################################
print()
print("[#################################### EL-PROCESS STARTED ####################################]")
print()
print()
################################################################


### Create engines

database_name = 'adventureworks2019'
mssqlserver_servername = 'DESKTOP-T3D2QGJ'

mssqlserver_uri = f"mssql+pyodbc://{os.environ.get('mssqlserver_user')}:{os.environ.get('mssqlserver_pass')}@{mssqlserver_servername}/{database_name}?driver=SQL+Server"
mssqlserver_engine = create_engine(mssqlserver_uri)

postgres_uri = f"postgres+psycopg2://{os.environ.get('postgres_user')}:{os.environ.get('postgres_pass')}@localhost:5432/{database_name}"
postgres_engine = create_engine(postgres_uri)


################################################################
print(f"Engines created for database {database_name}")
print()
print()
################################################################


### Query all tables, including views

mssqlserver_table_query = """

    SELECT
          t.name AS table_name
        , s.name AS schema_name
    FROM sys.tables t
    INNER JOIN sys.schemas s
    ON t.schema_id = s.schema_id

    UNION

    SELECT
          v.name AS table_name
        , s.name AS schema_name
    FROM sys.views v
    INNER JOIN sys.schemas s
    ON v.schema_id = s.schema_id

    ORDER BY schema_name, table_name;

"""

mssqlserver_connection = mssqlserver_engine.connect()

mssqlserver_tables = mssqlserver_connection.execute(mssqlserver_table_query)
mssqlserver_tables = mssqlserver_tables.fetchall()
mssqlserver_tables = dict(mssqlserver_tables)

mssqlserver_schemas = set(mssqlserver_tables.values())

mssqlserver_connection.close()

################################################################
print(f"Tables collected. Found {len(mssqlserver_tables)} tables in {len(mssqlserver_schemas)} schemas.")
print()
print()
################################################################


### Schema creation

postgres_connection = postgres_engine.connect()

for schema in mssqlserver_schemas:
    schema_create = f"""

        DROP SCHEMA IF EXISTS "{schema.lower()}" CASCADE;
        CREATE SCHEMA"{schema.lower()}";

    """

    postgres_connection.execute(schema_create) 
    print(f" - Schema {schema.lower()} created")

postgres_connection.close()


################################################################
print()
print(f"Schemas created.")
print()
print()
################################################################


### Table dump

for table_name, schema_name in mssqlserver_tables.items():
    
    table_no = list(mssqlserver_tables.keys()).index(f"{table_name}") + 1
    ################################################################
    print()
    print(f"##### Dumping table No. {table_no} from {len(mssqlserver_tables)}: {schema_name}.{table_name}...")
    ################################################################
    
    mssqlserver_connection = mssqlserver_engine.connect()
    postgres_connection = postgres_engine.connect()
    
    table_split = [t for t in re.split("([A-Z][^A-Z]*)", table_name) if t]
    table_split = '_'.join(table_split)
    table_split = table_split.lower()
    
    ################################################################
    print(f"    . Converted {table_name} to --> {table_split}")
    ################################################################
    
    full_table = f"""

        SELECT
        *
        FROM {schema_name}.{table_name};

    """
    
    df = pd.read_sql(full_table, mssqlserver_connection)
    df.columns = map(str.lower, df.columns)
    df.to_sql(schema=schema_name.lower(), name=table_split, con=postgres_connection, chunksize=5000, index=False, index_label=False, if_exists='replace')
    
    ################################################################
    print(f"   .. Wrote {schema_name}.{table_split} to database")
    ################################################################
    
    
    postgres_connection.close()
    mssqlserver_connection.close()


mssqlserver_engine.dispose()
postgres_engine.dispose()


print()
print()
print("Engines disposed")
print()
print()
print("[#################################### EL-PROCESS FINISHED ####################################"])
print()
# Out:
# #################################### EL-PROCESS STARTED ####################################
#
#
# Engines created for database adventureworks2019
#
#
# Tables collected. Found 91 tables in 6 schemas.
#
#
#  - Schema person created
#  - Schema production created
#  - Schema sales created
#  - Schema purchasing created
#  - Schema dbo created
#  - Schema humanresources created
#
# Schemas created.
#
#
#
# ##### Dumping table No. 1 from 91: dbo.AWBuildVersion...
#     . Converted AWBuildVersion to --> a_w_build_version
#    .. Wrote dbo.a_w_build_version to database
#
# ##### Dumping table No. 2 from 91: dbo.DatabaseLog...
#     . Converted DatabaseLog to --> database_log
#    .. Wrote dbo.database_log to database
#
# ##### Dumping table No. 3 from 91: dbo.ErrorLog...
#     . Converted ErrorLog to --> error_log
#    .. Wrote dbo.error_log to database
#
# ##### Dumping table No. 4 from 91: HumanResources.Department...
#     . Converted Department to --> department
#    .. Wrote HumanResources.department to database
#
# ##### Dumping table No. 5 from 91: HumanResources.Employee...
#     . Converted Employee to --> employee
#    .. Wrote HumanResources.employee to database
#
# ##### Dumping table No. 6 from 91: HumanResources.EmployeeDepartmentHistory...
#     . Converted EmployeeDepartmentHistory to --> employee_department_history
#    .. Wrote HumanResources.employee_department_history to database
#
# ##### Dumping table No. 7 from 91: HumanResources.EmployeePayHistory...
#     . Converted EmployeePayHistory to --> employee_pay_history
#    .. Wrote HumanResources.employee_pay_history to database
#
# ##### Dumping table No. 8 from 91: HumanResources.JobCandidate...
#     . Converted JobCandidate to --> job_candidate
#    .. Wrote HumanResources.job_candidate to database
#
# ##### Dumping table No. 9 from 91: HumanResources.Shift...
#     . Converted Shift to --> shift
#    .. Wrote HumanResources.shift to database
#
# ##### Dumping table No. 10 from 91: HumanResources.vEmployee...
#     . Converted vEmployee to --> v_employee
#    .. Wrote HumanResources.v_employee to database
#
# ##### Dumping table No. 11 from 91: HumanResources.vEmployeeDepartment...
#     . Converted vEmployeeDepartment to --> v_employee_department
#    .. Wrote HumanResources.v_employee_department to database
#
# ##### Dumping table No. 12 from 91: HumanResources.vEmployeeDepartmentHistory...
#     . Converted vEmployeeDepartmentHistory to --> v_employee_department_history
#    .. Wrote HumanResources.v_employee_department_history to database
#
# ##### Dumping table No. 13 from 91: HumanResources.vJobCandidate...
#     . Converted vJobCandidate to --> v_job_candidate
#    .. Wrote HumanResources.v_job_candidate to database
#
# ##### Dumping table No. 14 from 91: HumanResources.vJobCandidateEducation...
#     . Converted vJobCandidateEducation to --> v_job_candidate_education
#    .. Wrote HumanResources.v_job_candidate_education to database
#
# ##### Dumping table No. 15 from 91: HumanResources.vJobCandidateEmployment...
#     . Converted vJobCandidateEmployment to --> v_job_candidate_employment
#    .. Wrote HumanResources.v_job_candidate_employment to database
#
# ##### Dumping table No. 16 from 91: Person.Address...
#     . Converted Address to --> address
#    .. Wrote Person.address to database
#
# ##### Dumping table No. 17 from 91: Person.AddressType...
#     . Converted AddressType to --> address_type
#    .. Wrote Person.address_type to database
#
# ##### Dumping table No. 18 from 91: Person.BusinessEntity...
#     . Converted BusinessEntity to --> business_entity
#    .. Wrote Person.business_entity to database
#
# ##### Dumping table No. 19 from 91: Person.BusinessEntityAddress...
#     . Converted BusinessEntityAddress to --> business_entity_address
#    .. Wrote Person.business_entity_address to database
#
# ##### Dumping table No. 20 from 91: Person.BusinessEntityContact...
#     . Converted BusinessEntityContact to --> business_entity_contact
#    .. Wrote Person.business_entity_contact to database
#
# ##### Dumping table No. 21 from 91: Person.ContactType...
#     . Converted ContactType to --> contact_type
#    .. Wrote Person.contact_type to database
#
# ##### Dumping table No. 22 from 91: Person.CountryRegion...
#     . Converted CountryRegion to --> country_region
#    .. Wrote Person.country_region to database
#
# ##### Dumping table No. 23 from 91: Person.EmailAddress...
#     . Converted EmailAddress to --> email_address
#    .. Wrote Person.email_address to database
#
# ##### Dumping table No. 24 from 91: Person.Password...
#     . Converted Password to --> password
#    .. Wrote Person.password to database
#
# ##### Dumping table No. 25 from 91: Person.Person...
#     . Converted Person to --> person
#    .. Wrote Person.person to database
#
# ##### Dumping table No. 26 from 91: Person.PersonPhone...
#     . Converted PersonPhone to --> person_phone
#    .. Wrote Person.person_phone to database
#
# ##### Dumping table No. 27 from 91: Person.PhoneNumberType...
#     . Converted PhoneNumberType to --> phone_number_type
#    .. Wrote Person.phone_number_type to database
#
# ##### Dumping table No. 28 from 91: Person.StateProvince...
#     . Converted StateProvince to --> state_province
#    .. Wrote Person.state_province to database
#
# ##### Dumping table No. 29 from 91: Person.vAdditionalContactInfo...
#     . Converted vAdditionalContactInfo to --> v_additional_contact_info
#    .. Wrote Person.v_additional_contact_info to database
#
# ##### Dumping table No. 30 from 91: Person.vStateProvinceCountryRegion...
#     . Converted vStateProvinceCountryRegion to --> v_state_province_country_region
#    .. Wrote Person.v_state_province_country_region to database
#
# ##### Dumping table No. 31 from 91: Production.BillOfMaterials...
#     . Converted BillOfMaterials to --> bill_of_materials
#    .. Wrote Production.bill_of_materials to database
#
# ##### Dumping table No. 32 from 91: Production.Culture...
#     . Converted Culture to --> culture
#    .. Wrote Production.culture to database
#
# ##### Dumping table No. 33 from 91: Production.Document...
#     . Converted Document to --> document
#    .. Wrote Production.document to database
#
# ##### Dumping table No. 34 from 91: Production.Illustration...
#     . Converted Illustration to --> illustration
#    .. Wrote Production.illustration to database
#
# ##### Dumping table No. 35 from 91: Production.Location...
#     . Converted Location to --> location
#    .. Wrote Production.location to database
#
# ##### Dumping table No. 36 from 91: Production.Product...
#     . Converted Product to --> product
#    .. Wrote Production.product to database
#
# ##### Dumping table No. 37 from 91: Production.ProductCategory...
#     . Converted ProductCategory to --> product_category
#    .. Wrote Production.product_category to database
#
# ##### Dumping table No. 38 from 91: Production.ProductCostHistory...
#     . Converted ProductCostHistory to --> product_cost_history
#    .. Wrote Production.product_cost_history to database
#
# ##### Dumping table No. 39 from 91: Production.ProductDescription...
#     . Converted ProductDescription to --> product_description
#    .. Wrote Production.product_description to database
#
# ##### Dumping table No. 40 from 91: Production.ProductDocument...
#     . Converted ProductDocument to --> product_document
#    .. Wrote Production.product_document to database
#
# ##### Dumping table No. 41 from 91: Production.ProductInventory...
#     . Converted ProductInventory to --> product_inventory
#    .. Wrote Production.product_inventory to database
#
# ##### Dumping table No. 42 from 91: Production.ProductListPriceHistory...
#     . Converted ProductListPriceHistory to --> product_list_price_history
#    .. Wrote Production.product_list_price_history to database
#
# ##### Dumping table No. 43 from 91: Production.ProductModel...
#     . Converted ProductModel to --> product_model
#    .. Wrote Production.product_model to database
#
# ##### Dumping table No. 44 from 91: Production.ProductModelIllustration...
#     . Converted ProductModelIllustration to --> product_model_illustration
#    .. Wrote Production.product_model_illustration to database
#
# ##### Dumping table No. 45 from 91: Production.ProductModelProductDescriptionCulture...
#     . Converted ProductModelProductDescriptionCulture to --> product_model_product_description_culture
#    .. Wrote Production.product_model_product_description_culture to database
#
# ##### Dumping table No. 46 from 91: Production.ProductPhoto...
#     . Converted ProductPhoto to --> product_photo
#    .. Wrote Production.product_photo to database
#
# ##### Dumping table No. 47 from 91: Production.ProductProductPhoto...
#     . Converted ProductProductPhoto to --> product_product_photo
#    .. Wrote Production.product_product_photo to database
#
# ##### Dumping table No. 48 from 91: Production.ProductReview...
#     . Converted ProductReview to --> product_review
#    .. Wrote Production.product_review to database
#
# ##### Dumping table No. 49 from 91: Production.ProductSubcategory...
#     . Converted ProductSubcategory to --> product_subcategory
#    .. Wrote Production.product_subcategory to database
#
# ##### Dumping table No. 50 from 91: Production.ScrapReason...
#     . Converted ScrapReason to --> scrap_reason
#    .. Wrote Production.scrap_reason to database
#
# ##### Dumping table No. 51 from 91: Production.TransactionHistory...
#     . Converted TransactionHistory to --> transaction_history
#    .. Wrote Production.transaction_history to database
#
# ##### Dumping table No. 52 from 91: Production.TransactionHistoryArchive...
#     . Converted TransactionHistoryArchive to --> transaction_history_archive
#    .. Wrote Production.transaction_history_archive to database
#
# ##### Dumping table No. 53 from 91: Production.UnitMeasure...
#     . Converted UnitMeasure to --> unit_measure
#    .. Wrote Production.unit_measure to database
#
# ##### Dumping table No. 54 from 91: Production.vProductAndDescription...
#     . Converted vProductAndDescription to --> v_product_and_description
#    .. Wrote Production.v_product_and_description to database
#
# ##### Dumping table No. 55 from 91: Production.vProductModelCatalogDescription...
#     . Converted vProductModelCatalogDescription to --> v_product_model_catalog_description
#    .. Wrote Production.v_product_model_catalog_description to database
#
# ##### Dumping table No. 56 from 91: Production.vProductModelInstructions...
#     . Converted vProductModelInstructions to --> v_product_model_instructions
#    .. Wrote Production.v_product_model_instructions to database
#
# ##### Dumping table No. 57 from 91: Production.WorkOrder...
#     . Converted WorkOrder to --> work_order
#    .. Wrote Production.work_order to database
#
# ##### Dumping table No. 58 from 91: Production.WorkOrderRouting...
#     . Converted WorkOrderRouting to --> work_order_routing
#    .. Wrote Production.work_order_routing to database
#
# ##### Dumping table No. 59 from 91: Purchasing.ProductVendor...
#     . Converted ProductVendor to --> product_vendor
#    .. Wrote Purchasing.product_vendor to database
#
# ##### Dumping table No. 60 from 91: Purchasing.PurchaseOrderDetail...
#     . Converted PurchaseOrderDetail to --> purchase_order_detail
#    .. Wrote Purchasing.purchase_order_detail to database
#
# ##### Dumping table No. 61 from 91: Purchasing.PurchaseOrderHeader...
#     . Converted PurchaseOrderHeader to --> purchase_order_header
#    .. Wrote Purchasing.purchase_order_header to database
#
# ##### Dumping table No. 62 from 91: Purchasing.ShipMethod...
#     . Converted ShipMethod to --> ship_method
#    .. Wrote Purchasing.ship_method to database
#
# ##### Dumping table No. 63 from 91: Purchasing.Vendor...
#     . Converted Vendor to --> vendor
#    .. Wrote Purchasing.vendor to database
#
# ##### Dumping table No. 64 from 91: Purchasing.vVendorWithAddresses...
#     . Converted vVendorWithAddresses to --> v_vendor_with_addresses
#    .. Wrote Purchasing.v_vendor_with_addresses to database
#
# ##### Dumping table No. 65 from 91: Purchasing.vVendorWithContacts...
#     . Converted vVendorWithContacts to --> v_vendor_with_contacts
#    .. Wrote Purchasing.v_vendor_with_contacts to database
#
# ##### Dumping table No. 66 from 91: Sales.CountryRegionCurrency...
#     . Converted CountryRegionCurrency to --> country_region_currency
#    .. Wrote Sales.country_region_currency to database
#
# ##### Dumping table No. 67 from 91: Sales.CreditCard...
#     . Converted CreditCard to --> credit_card
#    .. Wrote Sales.credit_card to database
#
# ##### Dumping table No. 68 from 91: Sales.Currency...
#     . Converted Currency to --> currency
#    .. Wrote Sales.currency to database
#
# ##### Dumping table No. 69 from 91: Sales.CurrencyRate...
#     . Converted CurrencyRate to --> currency_rate
#    .. Wrote Sales.currency_rate to database
#
# ##### Dumping table No. 70 from 91: Sales.Customer...
#     . Converted Customer to --> customer
#    .. Wrote Sales.customer to database
#
# ##### Dumping table No. 71 from 91: Sales.PersonCreditCard...
#     . Converted PersonCreditCard to --> person_credit_card
#    .. Wrote Sales.person_credit_card to database
#
# ##### Dumping table No. 72 from 91: Sales.SalesOrderDetail...
#     . Converted SalesOrderDetail to --> sales_order_detail
#    .. Wrote Sales.sales_order_detail to database
#
# ##### Dumping table No. 73 from 91: Sales.SalesOrderHeader...
#     . Converted SalesOrderHeader to --> sales_order_header
#    .. Wrote Sales.sales_order_header to database
#
# ##### Dumping table No. 74 from 91: Sales.SalesOrderHeaderSalesReason...
#     . Converted SalesOrderHeaderSalesReason to --> sales_order_header_sales_reason
#    .. Wrote Sales.sales_order_header_sales_reason to database
#
# ##### Dumping table No. 75 from 91: Sales.SalesPerson...
#     . Converted SalesPerson to --> sales_person
#    .. Wrote Sales.sales_person to database
#
# ##### Dumping table No. 76 from 91: Sales.SalesPersonQuotaHistory...
#     . Converted SalesPersonQuotaHistory to --> sales_person_quota_history
#    .. Wrote Sales.sales_person_quota_history to database
#
# ##### Dumping table No. 77 from 91: Sales.SalesReason...
#     . Converted SalesReason to --> sales_reason
#    .. Wrote Sales.sales_reason to database
#
# ##### Dumping table No. 78 from 91: Sales.SalesTaxRate...
#     . Converted SalesTaxRate to --> sales_tax_rate
#    .. Wrote Sales.sales_tax_rate to database
#
# ##### Dumping table No. 79 from 91: Sales.SalesTerritory...
#     . Converted SalesTerritory to --> sales_territory
#    .. Wrote Sales.sales_territory to database
#
# ##### Dumping table No. 80 from 91: Sales.SalesTerritoryHistory...
#     . Converted SalesTerritoryHistory to --> sales_territory_history
#    .. Wrote Sales.sales_territory_history to database
#
# ##### Dumping table No. 81 from 91: Sales.ShoppingCartItem...
#     . Converted ShoppingCartItem to --> shopping_cart_item
#    .. Wrote Sales.shopping_cart_item to database
#
# ##### Dumping table No. 82 from 91: Sales.SpecialOffer...
#     . Converted SpecialOffer to --> special_offer
#    .. Wrote Sales.special_offer to database
#
# ##### Dumping table No. 83 from 91: Sales.SpecialOfferProduct...
#     . Converted SpecialOfferProduct to --> special_offer_product
#    .. Wrote Sales.special_offer_product to database
#
# ##### Dumping table No. 84 from 91: Sales.Store...
#     . Converted Store to --> store
#    .. Wrote Sales.store to database
#
# ##### Dumping table No. 85 from 91: Sales.vIndividualCustomer...
#     . Converted vIndividualCustomer to --> v_individual_customer
#    .. Wrote Sales.v_individual_customer to database
#
# ##### Dumping table No. 86 from 91: Sales.vPersonDemographics...
#     . Converted vPersonDemographics to --> v_person_demographics
#    .. Wrote Sales.v_person_demographics to database
#
# ##### Dumping table No. 87 from 91: Sales.vSalesPerson...
#     . Converted vSalesPerson to --> v_sales_person
#    .. Wrote Sales.v_sales_person to database
#
# ##### Dumping table No. 88 from 91: Sales.vSalesPersonSalesByFiscalYears...
#     . Converted vSalesPersonSalesByFiscalYears to --> v_sales_person_sales_by_fiscal_years
#    .. Wrote Sales.v_sales_person_sales_by_fiscal_years to database
#
# ##### Dumping table No. 89 from 91: Sales.vStoreWithAddresses...
#     . Converted vStoreWithAddresses to --> v_store_with_addresses
#    .. Wrote Sales.v_store_with_addresses to database
#
# ##### Dumping table No. 90 from 91: Sales.vStoreWithContacts...
#     . Converted vStoreWithContacts to --> v_store_with_contacts
#    .. Wrote Sales.v_store_with_contacts to database
#
# ##### Dumping table No. 91 from 91: Sales.vStoreWithDemographics...
#     . Converted vStoreWithDemographics to --> v_store_with_demographics
#    .. Wrote Sales.v_store_with_demographics to database
#
#
# Engines disposed
#
#
# #################################### EL-PROCESS FINISHED ####################################
